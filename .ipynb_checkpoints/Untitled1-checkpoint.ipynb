# %%
# New Convolution

# %%
import matplotlib.pyplot as plt
# %matplotlib inline
import pandas as pd
import numpy as np
import math
import glob
import cv2
import os
import tensorflow as tf

path = '/Users/tae/Desktop/Project/image/*'
# path_export = '/Users/tae/Desktop/Project/Dataset/unnormalize/Convolution48.xlsx'
# size_columns = 48

# %%
image_path = glob.glob(path+'/*')[0]
img =plt.imread(image_path)
gray = cv2.cvtColor(img , cv2.COLOR_RGB2GRAY)
plt.imshow(gray , cmap='gray')

# %%
#convolution
# padding
padded_data = tf.pad(gray, [[1, 1], [1, 1]], mode='constant')

# %%
gray
# Out:
# array([[213, 210, 211, ...,  90,  62,  86],
#        [216, 213, 213, ...,  86,  60,  77],
#        [215, 212, 213, ...,  90,  67,  74],
#        ...,
#        [206, 204, 202, ..., 165, 158, 148],
#        [204, 205, 207, ..., 162, 157, 150],
#        [204, 207, 211, ..., 160, 158, 152]], dtype=uint8)

# %%
gray
# Out:
# array([[213, 210, 211, ...,  90,  62,  86],
#        [216, 213, 213, ...,  86,  60,  77],
#        [215, 212, 213, ...,  90,  67,  74],
#        ...,
#        [206, 204, 202, ..., 165, 158, 148],
#        [204, 205, 207, ..., 162, 157, 150],
#        [204, 207, 211, ..., 160, 158, 152]], dtype=uint8)

# %%
gray[:3, 243:2]

# %%
new_height = math.floor(gray.shape[0] / 3)
new_width = math.floor(gray.shape[1] / 3)

new_image = np.zeros((new_height2,new_width2))
kernel = np.array([ [0,-1,0],
                    [-1,5,-1],
                    [0,-1,0]])

for h in range(new_height-1):
    for w in range(new_width-1):
        s_height = h * 3
        e_height = (h+1) * 3
        s_width = w * 3 
        e_width = (w+1) * 3
        value = gray[s_height:e_height , s_width:e_width]
        result = np.sum(value * kernel)
        new_image
# Out:
# 214
# 218
# 213
# 205
# 214
# 228
# 209
# 223
# 216
# 220
# 209
# 209
# 210
# 192
# 210
# 210
# 187
# 193
# 194
# 207
# 205
# 172
# 201
# 188
# 214
# 217
# 220
# 158
# 177
# 190
# 162
# 139
# 173
# 277
# 284
# 82
# 242
# 241
# 185
# 158
# 212
# 145
# 179
# 147
# 139
# 304
# 145
# 197
# 114
# 165
# 234
# 177
# 107
# 163
# 152
# 222
# 332
# -24
# 269
# 165
# 47
# 303
# -54
# 267
# 164
# 179
# 212
# 359
# 124
# 70
# 227
# 98
# 167
# 142
# 148
# 117
# 165
# 72
# 107
# 108
# 200
# 227
# 230
# 207
# 230
# 231
# 239
# 234
# 230
# 222
# 210
# 200
# 230
# 211
# 223
# 203
# 212
# 222
# 181
# 222
# 189
# 216
# 206
# 202
# 201
# 208
# 192
# 186
# 178
# 148
# 212
# 124
# 222
# 351
# 147
# 146
# 151
# 188
# 198
# 222
# 157
# 173
# 142
# 208
# 246
# 143
# 187
# 195
# 326
# 214
# 199
# 220
# 175
# 213
# 197
# 181
# 27
# 93
# 4
# 22
# 225
# 258
# 26
# 64
# 276
# 233
# 141
# 277
# 39
# 80
# 179
# 121
# 9
# 94
# 31
# 1
# 47
# 31
# 57
# 105
# 208
# 234
# 219
# 248
# 195
# 215
# 218
# 208
# 229
# 200
# ...
